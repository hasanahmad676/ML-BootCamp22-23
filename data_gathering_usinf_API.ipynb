# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/trending/all/day?api_key=7e4984a112cce2f8cf8051170e2a6495')

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/dKqa850uvbNSCaQCV4Im1XlzEtQ.jpg',
#   'id': 661374,
#   'title': 'Glass Onion: A Knives Out Mystery',
#   'original_language': 'en',
#   'original_title': 'Glass Onion: A Knives Out Mystery',
#   'overview': 'World-famous detective Benoit Blanc heads to Greece to peel back the layers of a mystery surrounding a tech billionaire and his eclectic crew of friends.',
#   'poster_path': '/vDGr1YdrlfbU9wxTOdpf3zChmv9.jpg',
#   'media_type': 'movie',
#   'genre_ids': [9648, 53, 35],
#   'popularity': 1264.676,
#   'release_date': '2022-11-23',
#   'video': False,
#   'vote_average': 7.051,
#   'vote_count': 1272},
#  {'adult': False,
#   'backdrop_path': '/s16H6tpK2utvwDtzZ8Qy4qm5Emw.jpg',
#   'id': 76600,
#   'title': 'Avatar: The Way of Water',
#   'original_language': 'en',
#   'original_title': 'Avatar: The Way of Water',
# ...

# %%
df=pd.DataFrame(response.json()['results'])

# %%
df.head()
# Out:
#    adult                     backdrop_path      id  \
# 0  False  /dKqa850uvbNSCaQCV4Im1XlzEtQ.jpg  661374
# 1  False  /s16H6tpK2utvwDtzZ8Qy4qm5Emw.jpg   76600
# 2  False  /hoVuI69nygLQBJ4FqgRKnukDeKt.jpg  106541
# 3  False  /jG52tsazn04F1fe8hPZfVv7ICKt.jpg  668482
# 4  False  /1rukJHAP5p6DNHe75Oo1D0m3SnR.jpg  877269
#
#                                title original_language  \
# 0  Glass Onion: A Knives Out Mystery                en
# 1           Avatar: The Way of Water                en
# 2                                NaN                en
# 3   Roald Dahl's Matilda the Musical                en
# 4                      Strange World                en
#
#                       original_title  \
# 0  Glass Onion: A Knives Out Mystery
# 1           Avatar: The Way of Water
# 2                                NaN
# 3   Roald Dahl's Matilda the Musical
# 4                      Strange World
#
#                                             overview  \
# ...
