# %%
import pandas as pd

# %%
dict1 ={'Name':['Priyang','Aadhya','Krisha','Vedant','Parshv',
                'Mittal','Archana'],
                'Marks':[98,89,99,87,90,83,99],
                'Gender':['Male','Female','Female','Male','Male',
                         'Female','Female']
               }
df=pd.DataFrame(dict1)
df
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female
# 3   Vedant     87    Male
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %% [markdown]
# 1.Display Top 3 Rows of The Dataset

# %%
df.head(3)
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female

# %% [markdown]
# 2. Check Last 3 Rows of The **Dataset**

# %%
df.tail(3)
# Out:
#       Name  Marks  Gender
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %% [markdown]
# 3. Find Shape of Our Dataset (Number of Rows & Number of Columns)

# %%
rows=print("number of rows: ",df.shape[0])
Columns=print("number of columns: ",df.shape[1])
# Out:
# number of rows:  7
# number of columns:  3

# %% [markdown]
# 4. Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   Marks   7 non-null      int64
#  2   Gender  7 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 296.0+ bytes

# %% [markdown]
# 5.Check Null Values In The Dataset

# %%
df.isnull().sum()
# Out:
# Name      0
# Marks     0
# Gender    0
# dtype: int64

# %% [markdown]
# 6. Get Overall Statistics About The Dataframe

# %%
df.describe()
# Out:
#            Marks
# count   7.000000
# mean   92.142857
# std     6.491753
# min    83.000000
# 25%    88.000000
# 50%    90.000000
# 75%    98.500000
# max    99.000000

# %%
df.describe(include='all') # can get all statists value include object type data
# Out:
#            Name      Marks  Gender
# count         7   7.000000       7
# unique        7        NaN       2
# top     Priyang        NaN  Female
# freq          1        NaN       4
# mean        NaN  92.142857     NaN
# std         NaN   6.491753     NaN
# min         NaN  83.000000     NaN
# 25%         NaN  88.000000     NaN
# 50%         NaN  90.000000     NaN
# 75%         NaN  98.500000     NaN
# max         NaN  99.000000     NaN

# %% [markdown]
# 7.Find Unique Values From The Gender Column

# %%
df.columns
# Out:
# Index(['Name', 'Marks', 'Gender'], dtype='object')

# %% [markdown]
# 8. Find the Number of Unique values from the Gender column

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
# Out:
# Female    4
# Male      3
# Name: Gender, dtype: int64

# %% [markdown]
# 9. Display Count of Unique Values In Gender Column

# %%
df['Gender'].value_counts()
# Out:
# Female    4
# Male      3
# Name: Gender, dtype: int64

# %% [markdown]
# 10. Find Total Number of Students Having Marks Between 90 To 100 (Inclusive) Using Between Method

# %%
df[df['Marks']>= 90]
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 2   Krisha     99  Female
# 4   Parshv     90    Male
# 6  Archana     99  Female

# %%
df[df['Marks']<= 100]
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female
# 3   Vedant     87    Male
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %%
df[(df['Marks']>=90) & (df['Marks']<=100)]['Name']
# Out:
# 0    Priyang
# 2     Krisha
# 4     Parshv
# 6    Archana
# Name: Name, dtype: object

# %%
sum((df['Marks']>=90) & (df['Marks']<=100))
# Out:
# 4

# %%
sum(df['Marks'].between(90,100))
# Out:
# 4

# %% [markdown]
# 11. Find Average Marks

# %%
df['Marks'].mean()
# Out:
# 92.14285714285714

# %% [markdown]
# 12. Apply Method

# %%
def marks(x):
    return x/2

# %%
df['Half_Marks']=df['Marks'].apply(marks)

# %%
df
# Out:
#       Name  Marks  Gender  Half_Marks
# 0  Priyang     98    Male        49.0
# 1   Aadhya     89  Female        44.5
# 2   Krisha     99  Female        49.5
# 3   Vedant     87    Male        43.5
# 4   Parshv     90    Male        45.0
# 5   Mittal     83  Female        41.5
# 6  Archana     99  Female        49.5

# %%
df['Name'].apply(len)
# Out:
# 0    7
# 1    6
# 2    6
# 3    6
# 4    6
# 5    6
# 6    7
# Name: Name, dtype: int64

# %%
df['Marks'].apply(lambda x:x//2)
# Out:
# 0    49
# 1    44
# 2    49
# 3    43
# 4    45
# 5    41
# 6    49
# Name: Marks, dtype: int64

# %%
df
# Out:
#       Name  Marks  Gender  Half_Marks
# 0  Priyang     98    Male        49.0
# 1   Aadhya     89  Female        44.5
# 2   Krisha     99  Female        49.5
# 3   Vedant     87    Male        43.5
# 4   Parshv     90    Male        45.0
# 5   Mittal     83  Female        41.5
# 6  Archana     99  Female        49.5

# %% [markdown]
# 13. Map Function

# %%
df['New_Gendr']=df['Gender'].map({'Male':1,'Female':0})

# %%
df
# Out:
#       Name  Marks  Gender  Half_Marks  New_Gendr
# 0  Priyang     98    Male        49.0          1
# 1   Aadhya     89  Female        44.5          0
# 2   Krisha     99  Female        49.5          0
# 3   Vedant     87    Male        43.5          1
# 4   Parshv     90    Male        45.0          1
# 5   Mittal     83  Female        41.5          0
# 6  Archana     99  Female        49.5          0

# %% [markdown]
# 14. Drop the Column(s)

# %%
df.drop(['New_Gendr','Half_Marks'],axis=1 , inplace=True)

# %%
df
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female
# 3   Vedant     87    Male
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %% [markdown]
# 15. Print Name of the Columns

# %%
df.columns
# Out:
# Index(['Name', 'Marks', 'Gender'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %% [markdown]
# 16. Sort The Dataframe As Per The Marks Column

# %%
df.sort_values(by='Marks',ascending=False)
# Out:
#       Name  Marks  Gender
# 2   Krisha     99  Female
# 6  Archana     99  Female
# 0  Priyang     98    Male
# 4   Parshv     90    Male
# 1   Aadhya     89  Female
# 3   Vedant     87    Male
# 5   Mittal     83  Female

# %% [markdown]
# 17. Display Name & Marks of The Female Students

# %%
df[df['Gender']=='Female'][['Name','Marks']]
# Out:
#       Name  Marks
# 1   Aadhya     89
# 2   Krisha     99
# 5   Mittal     83
# 6  Archana     99

# %%
df[df['Gender'].str.contains('female',case=False)][['Name','Marks']]
# Out:
#       Name  Marks
# 1   Aadhya     89
# 2   Krisha     99
# 5   Mittal     83
# 6  Archana     99

# %%
df[df['Gender'].isin(['Female'])][['Name','Marks']]
# Out:
#       Name  Marks
# 1   Aadhya     89
# 2   Krisha     99
# 5   Mittal     83
# 6  Archana     99
