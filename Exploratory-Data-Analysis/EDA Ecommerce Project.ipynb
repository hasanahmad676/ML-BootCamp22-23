# %%
import pandas as pd

# %%
df=pd.read_csv('/content/new_data.csv',sep=',',error_bad_lines=False,names=['Address','Browser Info','Company','Credit Card','CC Exp Date','CC Security Code','Email','Job','IP Address','Language','Purchase Price'])
df.head()
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                                             Address  \
# Address                      Lot             AM or PM  Browser Info
# 16629 Pace Camp Apt. 448     NaN             NaN                NaN
# Alexisborough                 NE 77130-7478" 46 in               PM
# 9374 Jasmine Spurs Suite 508 NaN             NaN                NaN
# South John                    TN 84355-4179" 28 rn               PM
#
#                                                                                             Browser Info  \
# Address                      Lot             AM or PM                                            Company
# 16629 Pace Camp Apt. 448     NaN             NaN                                                     NaN
# ...

# %%
df.to_csv("/content/new_data.csv")

# %%
df=pd.read_csv("/content/new_data.csv",header=1)
df.head()
# Out:
#                         Address              Lot AM or PM Browser Info  \
# 0      16629 Pace Camp Apt. 448              NaN      NaN          NaN
# 1                 Alexisborough   NE 77130-7478"    46 in           PM
# 2  9374 Jasmine Spurs Suite 508              NaN      NaN          NaN
# 3                    South John   TN 84355-4179"    28 rn           PM
# 4            Unit 0065 Box 5052              NaN      NaN          NaN
#
#                                              Company  \
# 0                                                NaN
# 1  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 2                                                NaN
# 3  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 4                                                NaN
#
#                        Credit Card CC Exp Date CC Security Code CC Provider  \
# 0                              NaN         NaN              NaN         NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           20000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  object
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  object
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  object
# dtypes: object(14)
# memory usage: 2.1+ MB
